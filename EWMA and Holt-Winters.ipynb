# %%
# !wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# File ‘airline_passengers.csv’ already there; not retrieving.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)

# %%
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
df.isna().sum()
# Out:
# Passengers    0
# dtype: int64

# %%
df.plot();

# %%
alpha = 0.2

# %%
df['EWMA'] = df['Passengers'].ewm(alpha=alpha, adjust=False).mean()

# %%
type(df['Passengers'].ewm(alpha=alpha, adjust=False))
# Out:
# pandas.core.window.ewm.ExponentialMovingWindow

# %%
df.plot();

# %%
manual_ewma = []
for x in df['Passengers'].to_numpy():
  if len(manual_ewma) > 0:
    xhat = alpha * x + (1 - alpha) * manual_ewma[-1]
  else:
    xhat = x
  manual_ewma.append(xhat)
df['Manual'] = manual_ewma

# %%
df.plot();

# %%
df.head()
# Out:
#             Passengers      EWMA    Manual
# Month
# 1949-01-01         112  112.0000  112.0000
# 1949-02-01         118  113.2000  113.2000
# 1949-03-01         132  116.9600  116.9600
# 1949-04-01         129  119.3680  119.3680
# 1949-05-01         121  119.6944  119.6944

# %%
df.drop('Manual', axis=1, inplace=True)

# %%
# !pip install -U statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: pandas>=1.0 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.3.4)
# Requirement already satisfied: patsy>=0.5.2 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (23.1)
# Requirement already satisfied: numpy>=1.18 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->statsmodels) (2021.3)
# Requirement already satisfied: six in /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
ses = SimpleExpSmoothing(df['Passengers'])
# Out:
# /Users/tomaszosuchowski/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# link to offset aliases docs
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
df.index.freq = 'MS'

# %%
ses = SimpleExpSmoothing(
    df['Passengers'],
    initialization_method='legacy-heuristic')

# %%
res = ses.fit(smoothing_level=alpha, optimized=False)

# %%
res

# %%
res.predict(start=df.index[0], end=df.index[-1])
# Out:
# Month
# 1949-01-01    112.000000
# 1949-02-01    112.000000
# 1949-03-01    113.200000
# 1949-04-01    116.960000
# 1949-05-01    119.368000
#                  ...
# 1960-08-01    488.767616
# 1960-09-01    512.214093
# 1960-10-01    511.371274
# 1960-11-01    501.297019
# 1960-12-01    479.037615
# Freq: MS, Length: 144, dtype: float64

# %%
df['SES'] = res.predict(start=df.index[0], end=df.index[-1])

# %%
np.allclose(df['SES'], res.fittedvalues)
# Out:
# True

# %%
df.plot();

# %%
df.head()
# Out:
#             Passengers      EWMA      SES
# Month
# 1949-01-01         112  112.0000  112.000
# 1949-02-01         118  113.2000  112.000
# 1949-03-01         132  116.9600  113.200
# 1949-04-01         129  119.3680  116.960
# 1949-05-01         121  119.6944  119.368

# %%
df['SES-1'] = df['SES'].shift(-1)

# %%
### No!
df[['Passengers', 'EWMA', 'SES-1']].plot();

# %%
N_test = 12
train = df.iloc[:-N_test]
test = df.iloc[-N_test:]

# %%
ses = SimpleExpSmoothing(
    train['Passengers'],
    initialization_method='legacy-heuristic')
res = ses.fit()

# %%
# boolean series to index df rows
train_idx = df.index <= train.index[-1]
test_idx = df.index > train.index[-1]

# %%
df.loc[train_idx, 'SESfitted'] = res.fittedvalues
df.loc[test_idx, 'SESfitted'] = res.forecast(N_test)
df[['Passengers', 'SESfitted']].plot();

# %%
res.params
# Out:
# {'smoothing_level': 0.995,
#  'smoothing_trend': nan,
#  'smoothing_seasonal': nan,
#  'damping_trend': nan,
#  'initial_level': 112.0,
#  'initial_trend': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
from statsmodels.tsa.holtwinters import Holt

# %%
holt = Holt(
    df['Passengers'],
    initialization_method='legacy-heuristic')

# %%
res_h = holt.fit()

# %%
df['Holt'] = res_h.fittedvalues

# %%
df[['Passengers', 'Holt']].plot();

# %%
### No!
df['Holt-1'] = df['Holt'].shift(-1)
df[['Passengers', 'Holt-1']].plot();

# %%
holt = Holt(train['Passengers'], initialization_method='legacy-heuristic')
res_h = holt.fit()
df.loc[train_idx, 'Holt'] = res_h.fittedvalues

# %%
df.loc[test_idx, 'Holt'] = res_h.forecast(N_test)

# %%
df[['Passengers', 'Holt']].plot();

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
hw = ExponentialSmoothing(
    train['Passengers'],
    initialization_method='legacy-heuristic',
    trend='add', seasonal='add', seasonal_periods=12)
res_hw = hw.fit()

# %%
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues

# %%
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)

# %%
df[['Passengers', 'HoltWinters']].plot();

# %%
def rmse(y, t):
  return np.sqrt(np.mean((y - t)**2))

# %%
def mae(y, t):
  return np.mean(np.abs(y - t))

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 11.853008212243283
# Test RMSE: 15.543108622285583

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 8.892100628211816
# Test MAE: 10.438226336474727

# %%
hw = ExponentialSmoothing(
    train['Passengers'],
    initialization_method='legacy-heuristic',
    trend='add', seasonal='mul', seasonal_periods=12)
res_hw = hw.fit()
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)
df[['Passengers', 'HoltWinters']].plot();

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 10.15393483898055
# Test RMSE: 16.535211720311374

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 7.552052709682746
# Test MAE: 10.683341034978644

# %%
hw = ExponentialSmoothing(
    train['Passengers'],
    initialization_method='legacy-heuristic',
    trend='mul', seasonal='mul', seasonal_periods=12)
res_hw = hw.fit()
df.loc[train_idx, 'HoltWinters'] = res_hw.fittedvalues
df.loc[test_idx, 'HoltWinters'] = res_hw.forecast(N_test)
df[['Passengers', 'HoltWinters']].plot();

# %%
print("Train RMSE:", rmse(train['Passengers'], res_hw.fittedvalues))
print("Test RMSE:", rmse(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train RMSE: 9.8871781338136
# Test RMSE: 19.102057401833985

# %%
print("Train MAE:", mae(train['Passengers'], res_hw.fittedvalues))
print("Test MAE:", mae(test['Passengers'], res_hw.forecast(N_test)))
# Out:
# Train MAE: 7.408707892868203
# Test MAE: 13.450469349047376
